# %%
import pandas as p d
import numpy as np
import os

# %%
data = pd.read_excel('DATA2.xlsx')
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
DATA ANALYSIS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.duplicated().sum() #no duplicate columns
# Out:
# 0

# %%
data.isnull().sum() # no null values present
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data['Ram'] = data['Ram'].str.replace('GB','').astype('int32')
data['Weight'] = data['Weight'].str.replace('kg','').astype('float32')
data['Price'] = data['Price'].astype(int)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# 3            AMD Radeon Pro 455  macOS    1.83  135195
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095

# %%
data['Company'].unique() # everthing is fine
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
data['TypeName'].unique() # everything is fine
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
data['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
data['ScreenResolution'].unique() # make a lot of changes
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
#        'IPS Panel Quad HD+ 3200x1800',
#        'IPS Panel Quad HD+ / Touchscreen 3200x1800',
#        'IPS Panel Touchscreen 1366x768', '1920x1080',
#        'IPS Panel Full HD 1920x1200',
#        'IPS Panel Touchscreen / 4K Ultra HD 3840x2160',
#        'IPS Panel Touchscreen 2560x1440',
#        'Touchscreen / Full HD 1920x1080', 'Quad HD+ 3200x1800',
#        'Touchscreen / 4K Ultra HD 3840x2160',
#        'IPS Panel Touchscreen 2400x1600'], dtype=object)

# %%
data['Cpu'].unique() # need to make changes
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
#        'Intel Atom x5-Z8550 1.44GHz',
#        'Intel Celeron Dual Core N3060 1.6GHz', 'Intel Core i5 1.3GHz',
#        'AMD FX 9830P 3GHz', 'Intel Core i7 7560U 2.4GHz',
#        'AMD E-Series 6110 1.5GHz', 'Intel Core i5 6200U 2.3GHz',
#        'Intel Core M 6Y75 1.2GHz', 'Intel Core i5 7500U 2.7GHz',
#        'Intel Core i3 6006U 2.2GHz', 'AMD A6-Series 9220 2.9GHz',
#        'Intel Core i7 6920HQ 2.9GHz', 'Intel Core i5 7Y54 1.2GHz',
#        'Intel Core i7 7820HK 2.9GHz', 'Intel Xeon E3-1505M V6 3GHz',
#        'Intel Core i7 6500U 2.5GHz', 'AMD E-Series 9000e 1.5GHz',
#        'AMD A10-Series A10-9620P 2.5GHz', 'AMD A6-Series A6-9220 2.5GHz',
#        'Intel Core i5 2.9GHz', 'Intel Core i7 6600U 2.6GHz',
#        'Intel Core i3 6006U 2.0GHz',
#        'Intel Celeron Dual Core 3205U 1.5GHz',
#        'Intel Core i7 7820HQ 2.9GHz', 'AMD A10-Series 9600P 2.4GHz',
#        'Intel Core i7 7600U 2.8GHz', 'AMD A8-Series 7410 2.2GHz',
#        'Intel Celeron Dual Core 3855U 1.6GHz',
#        'Intel Pentium Quad Core N3710 1.6GHz',
#        'AMD A12-Series 9720P 2.7GHz', 'Intel Core i5 7300U 2.6GHz',
#        'AMD A12-Series 9720P 3.6GHz',
#        'Intel Celeron Quad Core N3450 1.1GHz',
#        'Intel Celeron Dual Core N3060 1.60GHz',
#        'Intel Core i5 6440HQ 2.6GHz', 'Intel Core i7 6820HQ 2.7GHz',
#        'AMD Ryzen 1600 3.2GHz', 'Intel Core i7 7Y75 1.3GHz',
#        'Intel Core i5 7440HQ 2.8GHz', 'Intel Core i7 7660U 2.5GHz',
#        'Intel Core i7 7700HQ 2.7GHz', 'Intel Core M m3-7Y30 2.2GHz',
#        'Intel Core i5 7Y57 1.2GHz', 'Intel Core i7 6700HQ 2.6GHz',
#        'Intel Core i3 6100U 2.3GHz', 'AMD A10-Series 9620P 2.5GHz',
#        'AMD E-Series 7110 1.8GHz', 'Intel Celeron Dual Core N3350 2.0GHz',
#        'AMD A9-Series A9-9420 3GHz', 'Intel Core i7 6820HK 2.7GHz',
#        'Intel Core M 7Y30 1.0GHz', 'Intel Xeon E3-1535M v6 3.1GHz',
#        'Intel Celeron Quad Core N3160 1.6GHz',
#        'Intel Core i5 6300U 2.4GHz', 'Intel Core i3 6100U 2.1GHz',
#        'AMD E-Series E2-9000 2.2GHz',
#        'Intel Celeron Dual Core N3050 1.6GHz',
#        'Intel Core M M3-6Y30 0.9GHz', 'AMD A9-Series 9420 2.9GHz',
#        'Intel Core i5 6300HQ 2.3GHz', 'AMD A6-Series 7310 2GHz',
#        'Intel Atom Z8350 1.92GHz', 'Intel Xeon E3-1535M v5 2.9GHz',
#        'Intel Core i5 6260U 1.8GHz',
#        'Intel Pentium Dual Core N4200 1.1GHz',
#        'Intel Celeron Quad Core N3710 1.6GHz', 'Intel Core M 1.2GHz',
#        'AMD A12-Series 9700P 2.5GHz', 'Intel Core i7 7500U 2.5GHz',
#        'Intel Pentium Dual Core 4405U 2.1GHz',
#        'AMD A4-Series 7210 2.2GHz', 'Intel Core i7 6560U 2.2GHz',
#        'Intel Core M m7-6Y75 1.2GHz', 'AMD FX 8800P 2.1GHz',
#        'Intel Core M M7-6Y75 1.2GHz', 'Intel Core i5 7200U 2.50GHz',
#        'Intel Core i5 7200U 2.70GHz', 'Intel Atom X5-Z8350 1.44GHz',
#        'Intel Core i5 7200U 2.7GHz', 'Intel Core M 1.1GHz',
#        'Intel Pentium Dual Core 4405Y 1.5GHz',
#        'Intel Pentium Quad Core N3700 1.6GHz', 'Intel Core M 6Y54 1.1GHz',
#        'Intel Core i7 6500U 2.50GHz',
#        'Intel Celeron Dual Core N3350 2GHz',
#        'Samsung Cortex A72&A53 2.0GHz', 'AMD E-Series 9000 2.2GHz',
#        'Intel Core M 6Y30 0.9GHz', 'AMD A9-Series 9410 2.9GHz'],
#       dtype=object)

# %%
import seaborn as sns
sns.distplot(data['Price'])
# Out:
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_12760\2171092255.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt
sns.barplot(x=data['Company'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=data['TypeName'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(data['Inches'])

# %%
sns.scatterplot(x=data['Inches'],y=data['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
data['Touchscreen']=data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
data.sample(10)
# Out:
#       Company   TypeName  Inches             ScreenResolution  \
# 392      Acer   Notebook    15.6           IPS Panel 1366x768
# 275      Dell   Notebook    15.6                     1366x768
# 170    Huawei  Ultrabook    13.0  IPS Panel Full HD 2160x1440
# 376    Lenovo    Netbook    11.6           IPS Panel 1366x768
# 51       Acer   Notebook    15.6  IPS Panel Full HD 1920x1080
# 1231    Razer     Gaming    14.0            Full HD 1920x1080
# 34      Apple  Ultrabook    13.3                     1440x900
# 248        HP   Notebook    13.3  IPS Panel Full HD 1920x1080
# 825   Toshiba   Notebook    14.0                     1366x768
# 611      Dell     Gaming    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram               Memory  \
# 392             Intel Core i5 8250U 1.6GHz   12              1TB HDD
# 275             Intel Core i7 7500U 2.7GHz   12              1TB HDD
# 170             Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 376   Intel Celeron Quad Core N3450 1.1GHz    4            128GB SSD
# 51              Intel Core i7 8550U 1.8GHz    8            256GB SSD
# 1231           Intel Core i7 7700HQ 2.8GHz   16              1TB SSD
# 34                    Intel Core i5 1.6GHz    8  256GB Flash Storage
# 248             Intel Core i5 8250U 1.6GHz    4            500GB HDD
# 825   Intel Pentium Dual Core 4405U 2.1GHz    4            128GB SSD
# 611            Intel Core i7 6700HQ 2.6GHz   16              1TB HDD
#
#                                  Gpu       OpSys  Weight   Price  Touchscreen
# 392             Nvidia GeForce MX130  Windows 10    2.20   36975            0
# 275            Intel HD Graphics 620  Windows 10    2.30   37992            0
# 170            Intel HD Graphics 620  Windows 10    1.05   71874            0
# 376            Intel HD Graphics 500  Windows 10    1.59   29463            0
# 51              Nvidia GeForce MX150  Windows 10    2.20   44808            0
# 1231         Nvidia GeForce GTX 1060  Windows 10    1.95  186426            0
# 34            Intel HD Graphics 6000    Mac OS X    1.35   53173            0
# 248           Intel UHD Graphics 620  Windows 10    1.49   35964            0
# 825            Intel HD Graphics 510  Windows 10    1.75   26586            0
# 611   Nvidia GeForce GTX 960<U+039C>  Windows 10    2.59   46833            0

# %%
data['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=data['Touchscreen'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['IPS']=data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
data.sample(6)
# Out:
#      Company   TypeName  Inches                 ScreenResolution  \
# 758     Dell     Gaming    15.6  IPS Panel 4K Ultra HD 3840x2160
# 257       HP   Notebook    17.3      IPS Panel Full HD 1920x1080
# 768  Samsung  Ultrabook    13.3  Full HD / Touchscreen 1920x1080
# 68    Lenovo   Notebook    15.6                Full HD 1920x1080
# 605      MSI     Gaming    15.6            4K Ultra HD 3840x2160
# 20      Asus    Netbook    11.6                         1366x768
#
#                              Cpu  Ram                Memory  \
# 758  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 257   Intel Core i7 8550U 1.8GHz   16               1TB HDD
# 768   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 68    Intel Core i5 7200U 2.5GHz    4               1TB HDD
# 605  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  2TB HDD
# 20   Intel Atom x5-Z8350 1.44GHz    2    32GB Flash Storage
#
#                          Gpu       OpSys  Weight   Price  Touchscreen  IPS
# 758  Nvidia GeForce GTX 1070  Windows 10    4.42  152859            0    1
# 257     Nvidia GeForce MX150  Windows 10    2.90   56423            0    1
# 768    Intel HD Graphics 620  Windows 10    1.31   85194            1    0
# 68     Intel HD Graphics 620  Windows 10    1.90   29250            0    0
# 605  Nvidia GeForce GTX 1060  Windows 10    1.80  122490            0    0
# 20     Intel HD Graphics 400  Windows 10    0.98   10224            0    0

# %%
data['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=data['IPS'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
DATA PREPROCESSING

# %%
new=data['ScreenResolution'].str.split('x',n=1,expand = True)

# %%
data['x_res'] = new[0]
data['y_res'] = new[1]
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#                            x_res y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
data['x_res'] = data['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#   x_res y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
data['x_res'] = data['x_res'].astype(int)
data['y_res'] = data['y_res'].astype(int)

# %%
data['ppi'] = (((data['x_res']**2) + (data['y_res']**2))**0.5/data['Inches']).astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int32
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# dtypes: float32(1), float64(2), int32(4), int64(2), object(7)
# memory usage: 137.6+ KB

# %%
data.drop(columns=['ScreenResolution','Inches','x_res','y_res'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
 data['Cpu Name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi       Cpu Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text =='Intel Core i5' or text  == 'Intel Core i7' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['Cpu brand'] = data['Cpu Name'].apply(fetch_processor)
data.sample(7)
# Out:
#     Company            TypeName                                   Cpu  Ram  \
# 469  Lenovo           Ultrabook            Intel Core i7 6600U 2.6GHz   12
# 578     MSI              Gaming           Intel Core i7 7820HK 2.9GHz   16
# 348    Asus  2 in 1 Convertible  Intel Celeron Dual Core N3350 1.1GHz    4
# 15    Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 672  Lenovo  2 in 1 Convertible            Intel Core i5 7200U 2.5GHz    8
# 699      HP            Notebook            Intel Core i7 7500U 2.7GHz    4
# 39       HP            Notebook            Intel Core i5 8250U 1.6GHz    8
#
#                    Memory                           Gpu       OpSys  Weight  \
# 469             256GB SSD         Intel HD Graphics 520  Windows 10    1.40
# 578  512GB SSD +  1TB HDD       Nvidia GeForce GTX 1070  Windows 10    4.14
# 348    32GB Flash Storage         Intel HD Graphics 500  Windows 10    1.50
# 15              256GB SSD  Intel Iris Plus Graphics 640       macOS    1.37
# 672             256GB SSD         Intel HD Graphics 620  Windows 10    1.30
# 699             500GB HDD                AMD Radeon 530  Windows 10    2.10
# 39              256GB SSD         Nvidia GeForce 930MX   Windows 10    2.10
#
#       Price  Touchscreen  IPS         ppi            Cpu Name  \
# 469   98994            0    1  209.800683       Intel Core i7
# 578  145401            0    0  127.335675       Intel Core i7
# 348   19980            1    0  135.094211  Intel Celeron Dual
# 15    80908            0    1  226.983005       Intel Core i5
# 672   55091            1    1  165.632118       Intel Core i5
# 699   36709            0    1  141.211998       Intel Core i7
# 39    46833            0    0  141.211998       Intel Core i5
#
#                  Cpu brand
# 469          Intel Core i7
# 578          Intel Core i7
# 348  Other Intel Processor
# 15           Intel Core i5
# 672          Intel Core i5
# 699          Intel Core i7
# 39           Intel Core i5

# %%
data['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=data['Cpu brand'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data.drop(columns=['Cpu','Cpu Name'],inplace=True)
data.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi      Cpu brand
# 0  macOS    1.37   71378            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095            0    1  226.983005  Intel Core i5

# %%
sns.barplot(x=data['Ram'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378            0
# 1           Intel HD Graphics 6000       macOS    1.34   47895            0
# 2            Intel HD Graphics 620       No OS    1.86   30636            0
# 3               AMD Radeon Pro 455       macOS    1.83  135195            0
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095            0
# ...                            ...         ...     ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992            1
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866            1
# 1300             Intel HD Graphics  Windows 10    1.50   12201            0
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705            0
# 1302             Intel HD Graphics  Windows 10    2.20   19660            0
#
#       IPS         ppi              Cpu brand
# 0       1  226.983005          Intel Core i5
# 1       0  127.677940          Intel Core i5
# 2       0  141.211998          Intel Core i5
# 3       1  220.534624          Intel Core i7
# 4       1  226.983005          Intel Core i5
# ...   ...         ...                    ...
# 1298    1  157.350512          Intel Core i7
# 1299    1  276.053530          Intel Core i7
# 1300    0  111.935204  Other Intel Processor
# 1301    0  100.454670          Intel Core i7
# 1302    0  100.454670  Other Intel Processor
#
# [1303 rows x 12 columns]

# %% [markdown]
# DATA PREPROCESSING

# %%
data['Memory'] = data['Memory'].astype(str).replace('\.0', '', regex=True)
data["Memory"] = data["Memory"].str.replace('GB', '')
data["Memory"] = data["Memory"].str.replace('TB', '000')
new = data["Memory"].str.split("+", n = 1, expand = True)

# %%
data
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378            0
# 1           Intel HD Graphics 6000       macOS    1.34   47895            0
# 2            Intel HD Graphics 620       No OS    1.86   30636            0
# 3               AMD Radeon Pro 455       macOS    1.83  135195            0
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095            0
# ...                            ...         ...     ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992            1
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866            1
# 1300             Intel HD Graphics  Windows 10    1.50   12201            0
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705            0
# 1302             Intel HD Graphics  Windows 10    2.20   19660            0
#
#       IPS         ppi              Cpu brand
# 0       1  226.983005          Intel Core i5
# 1       0  127.677940          Intel Core i5
# 2       0  141.211998          Intel Core i5
# 3       1  220.534624          Intel Core i7
# 4       1  226.983005          Intel Core i5
# ...   ...         ...                    ...
# 1298    1  157.350512          Intel Core i7
# 1299    1  276.053530          Intel Core i7
# 1300    0  111.935204  Other Intel Processor
# 1301    0  100.454670          Intel Core i7
# 1302    0  100.454670  Other Intel Processor
#
# [1303 rows x 12 columns]

# %%
data["first"]= new[0]
data["first"]= data["first"].str.strip()

# %%
data
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378            0
# 1           Intel HD Graphics 6000       macOS    1.34   47895            0
# 2            Intel HD Graphics 620       No OS    1.86   30636            0
# 3               AMD Radeon Pro 455       macOS    1.83  135195            0
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095            0
# ...                            ...         ...     ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992            1
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866            1
# 1300             Intel HD Graphics  Windows 10    1.50   12201            0
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705            0
# 1302             Intel HD Graphics  Windows 10    2.20   19660            0
#
#       IPS         ppi              Cpu brand              first
# 0       1  226.983005          Intel Core i5            128 SSD
# 1       0  127.677940          Intel Core i5  128 Flash Storage
# 2       0  141.211998          Intel Core i5            256 SSD
# 3       1  220.534624          Intel Core i7            512 SSD
# 4       1  226.983005          Intel Core i5            256 SSD
# ...   ...         ...                    ...                ...
# 1298    1  157.350512          Intel Core i7            128 SSD
# 1299    1  276.053530          Intel Core i7            512 SSD
# 1300    0  111.935204  Other Intel Processor   64 Flash Storage
# 1301    0  100.454670          Intel Core i7           1000 HDD
# 1302    0  100.454670  Other Intel Processor            500 HDD
#
# [1303 rows x 13 columns]

# %%
data["second"]= new[1]

# %%
data
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378            0
# 1           Intel HD Graphics 6000       macOS    1.34   47895            0
# 2            Intel HD Graphics 620       No OS    1.86   30636            0
# 3               AMD Radeon Pro 455       macOS    1.83  135195            0
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095            0
# ...                            ...         ...     ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992            1
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866            1
# 1300             Intel HD Graphics  Windows 10    1.50   12201            0
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705            0
# 1302             Intel HD Graphics  Windows 10    2.20   19660            0
#
#       IPS         ppi              Cpu brand              first second
# 0       1  226.983005          Intel Core i5            128 SSD   None
# 1       0  127.677940          Intel Core i5  128 Flash Storage   None
# 2       0  141.211998          Intel Core i5            256 SSD   None
# 3       1  220.534624          Intel Core i7            512 SSD   None
# 4       1  226.983005          Intel Core i5            256 SSD   None
# ...   ...         ...                    ...                ...    ...
# 1298    1  157.350512          Intel Core i7            128 SSD   None
# 1299    1  276.053530          Intel Core i7            512 SSD   None
# 1300    0  111.935204  Other Intel Processor   64 Flash Storage   None
# 1301    0  100.454670          Intel Core i7           1000 HDD   None
# 1302    0  100.454670  Other Intel Processor            500 HDD   None
#
# [1303 rows x 14 columns]

# %%
data.sample(6)
# Out:
#       Company     TypeName  Ram   Memory                    Gpu       OpSys  \
# 984   Toshiba     Notebook    4  500 HDD  Intel HD Graphics 520  Windows 10
# 1181   Lenovo    Ultrabook    6  256 SSD    Nvidia GeForce 920M  Windows 10
# 1143       HP  Workstation    8  256 SSD   Nvidia Quadro M1000M   Windows 7
# 1248   Lenovo     Notebook    8  256 SSD  Intel HD Graphics 620       No OS
# 155        HP     Notebook    6  256 SSD         AMD Radeon 520  Windows 10
# 1039       HP     Notebook    8  256 SSD  Intel HD Graphics 620  Windows 10
#
#       Weight   Price  Touchscreen  IPS         ppi      Cpu brand    first  \
# 984     1.75   48751            0    0  111.935204  Intel Core i5  500 HDD
# 1181    1.54   44275            0    0  141.211998  Intel Core i7  256 SSD
# 1143    2.59  118761            0    1  141.211998  Intel Core i7  256 SSD
# 1248    2.30   30529            0    1  141.211998  Intel Core i5  256 SSD
# 155     1.91   32980            0    0  141.211998  Intel Core i5  256 SSD
# 1039    1.64   53839            0    0  157.350512  Intel Core i5  256 SSD
#
#      second
# 984    None
# 1181   None
# 1143   None
# 1248   None
# 155    None
# 1039   None

# %%
data["Layer1HDD"] = data["first"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer1SSD"] = data["first"].apply(lambda x: 1 if "SSD" in x else 0)
data["Layer1Hybrid"] = data["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer1Flash_Storage"] = data["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
data.sample(9)
# Out:
#      Company            TypeName  Ram               Memory  \
# 624       HP            Notebook    4              500 HDD
# 808     Dell              Gaming   16              512 SSD
# 1142      HP  2 in 1 Convertible    8              256 SSD
# 14     Apple           Ultrabook    8              256 SSD
# 1206      HP            Notebook    8              256 SSD
# 72      Dell            Notebook    8              256 SSD
# 980     Dell  2 in 1 Convertible   12              512 SSD
# 476     Dell         Workstation    8              256 SSD
# 238     Asus              Gaming   32  512 SSD +  1000 HDD
#
#                              Gpu       OpSys  Weight   Price  Touchscreen  \
# 624        Intel HD Graphics 520   Windows 7    1.88   49656            0
# 808   Nvidia GeForce GTX 1050 Ti  Windows 10    2.62   89457            0
# 1142       Intel HD Graphics 520  Windows 10    1.48   86793            1
# 14         Intel HD Graphics 615       macOS    0.92   67260            0
# 1206       Intel HD Graphics 620  Windows 10    1.91   30849            0
# 72                AMD Radeon 530  Windows 10    2.20   46353            0
# 980        Intel HD Graphics 620  Windows 10    2.19   69210            1
# 476          Nvidia Quadro M1200  Windows 10    1.78  128298            0
# 238      Nvidia GeForce GTX 1080  Windows 10    4.70  207259            0
#
#       IPS         ppi              Cpu brand    first      second  Layer1HDD  \
# 624     0  100.454670          Intel Core i5  500 HDD        None          1
# 808     0  282.423996          Intel Core i7  512 SSD        None          0
# 1142    0  165.632118          Intel Core i5  256 SSD        None          0
# 14      1  226.415547  Other Intel Processor  256 SSD        None          0
# 1206    0  100.454670          Intel Core i5  256 SSD        None          0
# 72      0  141.211998          Intel Core i7  256 SSD        None          0
# 980     1  141.211998          Intel Core i7  512 SSD        None          0
# 476     0  141.211998          Intel Core i7  256 SSD        None          0
# 238     0  127.335675          Intel Core i7  512 SSD    1000 HDD          0
#
#       Layer1SSD  Layer1Hybrid  Layer1Flash_Storage
# 624           0             0                    0
# 808           1             0                    0
# 1142          1             0                    0
# 14            1             0                    0
# 1206          1             0                    0
# 72            1             0                    0
# 980           1             0                    0
# 476           1             0                    0
# 238           1             0                    0

# %%
data['first'] = data['first'].str.replace(r'\D', '')

# %%
data["second"].fillna("0", inplace = True)

# %%
data["Layer2HDD"] = data["second"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer2SSD"] = data["second"].apply(lambda x: 1 if "SSD" in x else 0) 
data["Layer2Hybrid"] = data["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer2Flash_Storage"] = data["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
data.sample(9)
# Out:
#       Company            TypeName  Ram            Memory  \
# 234      Acer  2 in 1 Convertible    8           256 SSD
# 66         HP            Notebook    4           500 HDD
# 412        HP            Notebook    4          1000 HDD
# 768   Samsung           Ultrabook    8           256 SSD
# 168      Acer            Notebook    8           256 SSD
# 453    Lenovo            Notebook    8           256 SSD
# 721        HP  2 in 1 Convertible    8           256 SSD
# 1286   Lenovo            Notebook    2  64 Flash Storage
# 86         HP           Ultrabook    8           256 SSD
#
#                            Gpu       OpSys  Weight  Price  Touchscreen  IPS  \
# 234      Intel HD Graphics 520  Windows 10    1.60  36709            1    1
# 66              AMD Radeon 520  Windows 10    1.86  23373            0    0
# 412             AMD Radeon 520  Windows 10    2.10  24988            0    0
# 768      Intel HD Graphics 620  Windows 10    1.31  85194            1    0
# 168       Nvidia GeForce MX150  Windows 10    3.00  45501            0    1
# 453      Intel HD Graphics 620  Windows 10    1.65  71661            0    0
# 721      Intel HD Graphics 620  Windows 10    1.58  44574            1    1
# 1286         Intel HD Graphics  Windows 10    1.50  12201            0    0
# 86    Nvidia GeForce GTX 940MX  Windows 10    1.83  37242            0    1
#
#       ...             first second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 234   ...           256 SSD      0         0         1             0
# 66    ...           500 HDD      0         1         0             0
# 412   ...          1000 HDD      0         1         0             0
# 768   ...           256 SSD      0         0         1             0
# 168   ...           256 SSD      0         0         1             0
# 453   ...           256 SSD      0         0         1             0
# 721   ...           256 SSD      0         0         1             0
# 1286  ...  64 Flash Storage      0         0         0             0
# 86    ...           256 SSD      0         0         1             0
#
#       Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# 234                     0          0          0             0
# 66                      0          0          0             0
# 412                     0          0          0             0
# 768                     0          0          0             0
# 168                     0          0          0             0
# 453                     0          0          0             0
# 721                     0          0          0             0
# 1286                    1          0          0             0
# 86                      0          0          0             0
#
#       Layer2Flash_Storage
# 234                     0
# 66                      0
# 412                     0
# 768                     0
# 168                     0
# 453                     0
# 721                     0
# 1286                    0
# 86                      0
#
# [9 rows x 22 columns]

# %%
data['second'] = data['second'].str.replace(r'\D', '')

# %%
data.sample(9)
# Out:
#      Company            TypeName  Ram               Memory  \
# 1184      HP            Notebook    6             1000 HDD
# 519     Asus              Gaming   16  256 SSD +  1000 HDD
# 243     Dell              Gaming    8              256 SSD
# 233     Dell            Notebook    8              256 SSD
# 1195      HP            Notebook   12  128 SSD +  1000 HDD
# 1104  Lenovo              Gaming   16              512 SSD
# 496   Lenovo            Notebook    8              256 SSD
# 730     Acer              Gaming   16  128 SSD +  1000 HDD
# 1186    Dell  2 in 1 Convertible   16              512 SSD
#
#                              Gpu       OpSys  Weight   Price  Touchscreen  \
# 1184     Nvidia GeForce GTX 960M  Windows 10    2.18   42570            0
# 519    Nvidia GeForce GTX1050 Ti  Windows 10    3.00   80133            0
# 243      Nvidia GeForce GTX 1050  Windows 10    2.56   46833            0
# 233        Intel HD Graphics 620  Windows 10    1.60   45767            0
# 1195     Nvidia GeForce GTX 1050  Windows 10    2.21   70702            0
# 1104  Nvidia GeForce GTX 1050 Ti  Windows 10    2.40   63882            0
# 496       Intel UHD Graphics 620  Windows 10    2.17   47893            0
# 730      Nvidia GeForce GTX 1060  Windows 10    4.20  103096            0
# 1186       Intel HD Graphics 620  Windows 10    2.09   62817            1
#
#       IPS  ...     first      second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 1184    1  ...  1000 HDD           0         1         0             0
# 519     0  ...   256 SSD    1000 HDD         0         1             0
# 243     0  ...   256 SSD           0         0         1             0
# 233     0  ...   256 SSD           0         0         1             0
# 1195    1  ...   128 SSD    1000 HDD         0         1             0
# 1104    0  ...   512 SSD           0         0         1             0
# 496     0  ...   256 SSD           0         0         1             0
# 730     1  ...   128 SSD    1000 HDD         0         1             0
# 1186    0  ...   512 SSD           0         0         1             0
#
#       Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# 1184                    0          0          0             0
# 519                     0          1          0             0
# 243                     0          0          0             0
# 233                     0          0          0             0
# 1195                    0          1          0             0
# 1104                    0          0          0             0
# 496                     0          0          0             0
# 730                     0          1          0             0
# 1186                    0          0          0             0
#
#       Layer2Flash_Storage
# 1184                    0
# 519                     0
# 243                     0
# 233                     0
# 1195                    0
# 1104                    0
# 496                     0
# 730                     0
# 1186                    0
#
# [9 rows x 22 columns]

# %%
data['first']=data['first'].str.split().str.get(0)

# %%
data.sample(9)
# Out:
#      Company            TypeName  Ram               Memory  \
# 1054    Dell           Ultrabook   16             1000 SSD
# 217       HP            Notebook    8              256 SSD
# 72      Dell            Notebook    8              256 SSD
# 52        HP            Notebook    4              256 SSD
# 1019      HP            Notebook    8              256 SSD
# 194     Dell  2 in 1 Convertible    8             1000 HDD
# 940       HP              Gaming    8  128 SSD +  1000 HDD
# 702   Lenovo            Notebook    8             1000 HDD
# 342       HP            Notebook    8             1000 HDD
#
#                           Gpu       OpSys  Weight   Price  Touchscreen  IPS  \
# 1054    Intel HD Graphics 620  Windows 10    1.20  120093            1    0
# 217      Nvidia GeForce 930MX  Windows 10    1.63   54931            0    0
# 72             AMD Radeon 530  Windows 10    2.20   46353            0    0
# 52     AMD Radeon R4 Graphics  Windows 10    1.86   21231            0    0
# 1019    Intel HD Graphics 520  Windows 10    1.43  118761            0    0
# 194    Intel UHD Graphics 620  Windows 10    1.62   44701            1    1
# 940   Nvidia GeForce GTX 965M  Windows 10    2.75   74538            0    1
# 702             AMD Radeon R7  Windows 10    2.20   22857            0    0
# 342     Nvidia GeForce 930MX   Windows 10    2.10   38148            0    1
#
#       ...  first      second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 1054  ...   1000           0         0         1             0
# 217   ...    256           0         0         1             0
# 72    ...    256           0         0         1             0
# 52    ...    256           0         0         1             0
# 1019  ...    256           0         0         1             0
# 194   ...   1000           0         1         0             0
# 940   ...    128    1000 HDD         0         1             0
# 702   ...   1000           0         1         0             0
# 342   ...   1000           0         1         0             0
#
#       Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# 1054                    0          0          0             0
# 217                     0          0          0             0
# 72                      0          0          0             0
# 52                      0          0          0             0
# 1019                    0          0          0             0
# 194                     0          0          0             0
# 940                     0          1          0             0
# 702                     0          0          0             0
# 342                     0          0          0             0
#
#       Layer2Flash_Storage
# 1054                    0
# 217                     0
# 72                      0
# 52                      0
# 1019                    0
# 194                     0
# 940                     0
# 702                     0
# 342                     0
#
# [9 rows x 22 columns]

# %%
data['second']=data['second'].str.split().str.get(0)

# %%
data.sample(9)
# Out:
#       Company            TypeName  Ram               Memory  \
# 1004  Toshiba            Notebook    4              128 SSD
# 234      Acer  2 in 1 Convertible    8              256 SSD
# 84       Acer            Notebook    4             1000 HDD
# 751        HP            Notebook    8              256 SSD
# 1284   Lenovo  2 in 1 Convertible    4              128 SSD
# 339      Dell            Notebook    8              256 SSD
# 1106      MSI              Gaming    8  128 SSD +  1000 HDD
# 194      Dell  2 in 1 Convertible    8             1000 HDD
# 672    Lenovo  2 in 1 Convertible    8              256 SSD
#
#                           Gpu       OpSys  Weight   Price  Touchscreen  IPS  \
# 1004    Intel HD Graphics 520  Windows 10    1.20   63669            0    0
# 234     Intel HD Graphics 520  Windows 10    1.60   36709            1    1
# 84              AMD Radeon R5  Windows 10    2.10   21045            0    0
# 751     Intel HD Graphics 520  Windows 10    1.84  101232            0    0
# 1284    Intel HD Graphics 520  Windows 10    1.80   33992            1    1
# 339      Nvidia GeForce 940MX  Windows 10    2.00   60885            0    0
# 1106  Nvidia GeForce GTX 960M  Windows 10    2.90   80516            0    0
# 194    Intel UHD Graphics 620  Windows 10    1.62   44701            1    1
# 672     Intel HD Graphics 620  Windows 10    1.30   55091            1    1
#
#       ...  first second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 1004  ...    128      0         0         1             0
# 234   ...    256      0         0         1             0
# 84    ...   1000      0         1         0             0
# 751   ...    256      0         0         1             0
# 1284  ...    128      0         0         1             0
# 339   ...    256      0         0         1             0
# 1106  ...    128   1000         0         1             0
# 194   ...   1000      0         1         0             0
# 672   ...    256      0         0         1             0
#
#       Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# 1004                    0          0          0             0
# 234                     0          0          0             0
# 84                      0          0          0             0
# 751                     0          0          0             0
# 1284                    0          0          0             0
# 339                     0          0          0             0
# 1106                    0          1          0             0
# 194                     0          0          0             0
# 672                     0          0          0             0
#
#       Layer2Flash_Storage
# 1004                    0
# 234                     0
# 84                      0
# 751                     0
# 1284                    0
# 339                     0
# 1106                    0
# 194                     0
# 672                     0
#
# [9 rows x 22 columns]

# %%
data["first"] = data["first"].astype(int)
data["second"] = data["second"].astype(int)

# %%
data["HDD"]=(data["first"]*data["Layer1HDD"]+data["second"]*data["Layer2HDD"])
data["SSD"]=(data["first"]*data["Layer1SSD"]+data["second"]*data["Layer2SSD"])
data["Hybrid"]=(data["first"]*data["Layer1Hybrid"]+data["second"]*data["Layer2Hybrid"])
data["Flash_Storage"]=(data["first"]*data["Layer1Flash_Storage"]+data["second"]*data["Layer2Flash_Storage"])

# %%
data.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage','Memory','Hybrid','Flash_Storage'],inplace=True)

# %%
data.sample(7)
# Out:
#       Company            TypeName  Ram                      Gpu       OpSys  \
# 274   Toshiba            Notebook    8      Nvidia GeForce 930M  Windows 10
# 420    Lenovo  2 in 1 Convertible   16  Nvidia GeForce GTX 1050  Windows 10
# 515      Asus             Netbook    2    Intel HD Graphics 500  Windows 10
# 1231    Razer              Gaming   16  Nvidia GeForce GTX 1060  Windows 10
# 906        HP             Netbook    8    Intel HD Graphics 620  Windows 10
# 645    Lenovo            Notebook    4        Intel HD Graphics  Windows 10
# 520    Lenovo              Gaming    8  Nvidia GeForce GTX 1060  Windows 10
#
#       Weight   Price  Touchscreen  IPS         ppi              Cpu brand  \
# 274     2.20   43263            0    0  100.454670          Intel Core i7
# 420     2.00  101178            1    1  282.423996          Intel Core i7
# 515     1.10   13053            0    0  135.094211  Other Intel Processor
# 1231    1.95  186426            0    0  157.350512          Intel Core i7
# 906     1.26   79014            0    0  176.232574          Intel Core i7
# 645     1.43   14598            0    0  111.935204  Other Intel Processor
# 520     3.20   74538            0    1  141.211998          Intel Core i7
#
#        HDD   SSD
# 274    500     0
# 420      0   512
# 515      0     0
# 1231     0  1000
# 906      0   512
# 645      0     0
# 520   1000   256

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Ram          1303 non-null   int32
#  3   Gpu          1303 non-null   object
#  4   OpSys        1303 non-null   object
#  5   Weight       1303 non-null   float32
#  6   Price        1303 non-null   int32
#  7   Touchscreen  1303 non-null   int64
#  8   IPS          1303 non-null   int64
#  9   ppi          1303 non-null   float64
#  10  Cpu brand    1303 non-null   object
#  11  HDD          1303 non-null   int64
#  12  SSD          1303 non-null   int64
# dtypes: float32(1), float64(1), int32(2), int64(4), object(5)
# memory usage: 117.2+ KB

# %%
data['Gpu brand'] = data['Gpu'].apply(lambda x:x.split()[0])
data.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD Gpu brand
# 0   71378            0    1  226.983005  Intel Core i5    0  128     Intel
# 1   47895            0    0  127.677940  Intel Core i5    0    0     Intel
# 2   30636            0    0  141.211998  Intel Core i5    0  256     Intel
# 3  135195            0    1  220.534624  Intel Core i7    0  512       AMD
# 4   96095            0    1  226.983005  Intel Core i5    0  256     Intel

# %%
data = data[data['Gpu brand'] != 'ARM']
data['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=data['Gpu brand'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_12760\2462585147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['Gpu'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=data['OpSys'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Other/Linux/No OS'

# %%
data['os'] = data['OpSys'].apply(cat_os)
data.drop(columns=['OpSys'],inplace = True)
# Out:
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_12760\2312546129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['os'] = data['OpSys'].apply(cat_os)
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_12760\2312546129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['OpSys'],inplace = True)

# %%
data.sample(9)
# Out:
#       Company            TypeName  Ram  Weight   Price  Touchscreen  IPS  \
# 1018  Toshiba            Notebook    8    1.47   79387            0    1
# 32         HP            Notebook    4    2.71   23389            0    0
# 647     Razer              Gaming   16    1.95  138474            0    0
# 785       MSI              Gaming   16    1.60  100752            0    1
# 694   Toshiba            Notebook    8    1.50   51841            0    1
# 1256     Asus              Gaming   16    4.00  101232            0    1
# 755    Lenovo  2 in 1 Convertible    8    1.30   63882            1    1
# 609      Acer            Notebook    4    1.60   18594            0    0
# 596    Lenovo  2 in 1 Convertible    8    1.37  107892            1    1
#
#              ppi              Cpu brand   HDD  SSD Gpu brand       os
# 1018  157.350512          Intel Core i5     0  256     Intel  windows
# 32    127.335675          AMD Processor   500    0       AMD  windows
# 647   157.350512          Intel Core i7     0  256    Nvidia  windows
# 785   157.350512          Intel Core i7  1000  256    Nvidia  windows
# 694   165.632118          Intel Core i5     0  256     Intel  windows
# 1256  127.335675          Intel Core i7  1000  128    Nvidia  windows
# 755   276.053530          Intel Core i5     0  256     Intel  windows
# 609   111.935204  Other Intel Processor     0    0     Intel  windows
# 596   165.632118          Intel Core i7     0  512     Intel  windows

# %%
sns.scatterplot(x=data['Weight'],y=data['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.distplot(np.log(data['Price']))
# Out:
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_12760\460424880.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x = data.drop(columns=['Price'])
y = np.log(data['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu brand   HDD  SSD Gpu brand                 os
# 0             Intel Core i5     0  128     Intel                Mac
# 1             Intel Core i5     0    0     Intel                Mac
# 2             Intel Core i5     0  256     Intel  Other/Linux/No OS
# 3             Intel Core i7     0  512       AMD                Mac
# 4             Intel Core i5     0  256     Intel                Mac
# ...                     ...   ...  ...       ...                ...
# 1298          Intel Core i7     0  128     Intel            windows
# 1299          Intel Core i7     0  512     Intel            windows
# 1300  Other Intel Processor     0    0     Intel            windows
# 1301          Intel Core i7  1000    0       AMD            windows
# 1302  Other Intel Processor   500    0     Intel            windows
#
# [1302 rows x 12 columns]

# %% [markdown]
# Model Selection

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2, random_state=6227)

# %%
#LINEAR REG.

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
# scores.append(r2_score(y_test,y_pred))
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# print(scores[np.argmax(scores)])
# print(np.argmax(scores))
# Out:
# r2 Score  0.8777441642057956
# MAE Score  0.1802572783217848
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#RIG REG

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score  0.8639472376520969
# MAE Score  0.19083370351799273
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 Score  0.8212932790152557
# MAE Score  0.20810319573371994

# %%
#DECISION TREE

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score  0.8466789832844878
# MAE Score  0.1899822787150069
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 Score  0.7903736139275606
# MAE Score  0.1944285006949698

# %%
#RANDOM FOREST

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15
                                )
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 Score  0.910650195727257
# MAE Score  0.14888758885842143

# %%
#EXTRA TREE

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None,
                              max_features=0.75,
                              max_depth=15
                                )
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 Score  0.9067889597080929
# MAE Score  0.15315984495533805

# %%
#ADABOOST

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,
                         learning_rate=1.0)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score  0.8229280891685398
# MAE Score  0.2270116410240978
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#GRADIENT BOOST

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=100)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score  0.9018550459702828
# MAE Score  0.1560507928075637
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Xgboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(max_depth=5,learning_rate=0.5)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# r2 Score  0.908741877018749
# MAE Score  0.14589567640511486

# %%
#Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf',rf),('gbdt',gbdt),('xgb',xgb),('et',et)],weights=[5,1,1,1])
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print("r2 Score ",r2_score(y_test,y_pred))
print("MAE Score ",mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Anirudh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 Score  0.910599977000476
# MAE Score  0.14909243817747622

# %% [markdown]
# #Random Forest gives maximum r2 score
# #Exporting model using random forest classifier

# %%
import pickle
pickle.dump(pipe, open('pipe.pkl', 'wb'))
pickle.dump(data, open('data.pkl', 'wb'))

# %%
data
# Out:
#      Company            TypeName  Ram  Weight   Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378            0    1
# 1      Apple           Ultrabook    8    1.34   47895            0    0
# 2         HP            Notebook    8    1.86   30636            0    0
# 3      Apple           Ultrabook   16    1.83  135195            0    1
# 4      Apple           Ultrabook    8    1.37   96095            0    1
# ...      ...                 ...  ...     ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866            1    1
# 1300  Lenovo            Notebook    2    1.50   12201            0    0
# 1301      HP            Notebook    6    2.19   40705            0    0
# 1302    Asus            Notebook    4    2.20   19660            0    0
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other Intel Processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other Intel Processor   500    0     Intel
#
#                      os
# 0                   Mac
# 1                   Mac
# 2     Other/Linux/No OS
# 3                   Mac
# 4                   Mac
# ...                 ...
# 1298            windows
# 1299            windows
# 1300            windows
# 1301            windows
# 1302            windows
#
# [1302 rows x 13 columns]
